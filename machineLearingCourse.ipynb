# %% [markdown]
# # Course for machine learing by FreeCode camp

# %%
print("Hallo Welt")

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.read_csv("magic04.data")

df = pd.read_csv("magic04.data", sep=",", header=None)
print(df)
